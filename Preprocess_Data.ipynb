# %%
import pandas as pd
import numpy as np
from pycountry_convert import country_name_to_country_alpha3 as name2code

# %% [markdown]
# ### Assign the Question and Question Group an index

# %%
data = pd.read_csv('data/data.csv', engine="python")
data = data.iloc[:,[0,-4,-2,-1]]
data.head()
# Out:
#   ResponseID                                     Question Group  \
# 0     r00000  Resources for employees with mental health dis...
# 1     r00000  Resources for employees with mental health dis...
# 2     r00000  Safe and supportive workplce for those with me...
# 3     r00000  Resources for employees with mental health dis...
# 4     r00000  Resources for employees with mental health dis...
#
#                                             Question  \
# 0  Does your employer provide mental health benef...
# 1  Do you know the options for mental health care...
# 2  Has your employer ever formally discussed ment...
# 3  Does your employer offer resources to learn mo...
# 4  Is your anonymity protected if you choose to t...
#
#                           Response
# 0  Not eligible for coverage / N/A
# 1                              NaN
# 2                               No
# 3                               No
# 4                     I don't know

# %%
# create dictonary of questions and index
Q = pd.DataFrame(data['Question'].value_counts())
Q = dict(zip(Q.index, range(len(Q))))
# create dictonary of question_groups and index
Q_group = pd.DataFrame(data['Question Group'].value_counts())
Q_group = dict(zip(Q_group.index, range(len(Q_group))))

# %%
# add new columns (Question idx and Question_Group idx)
data['Q'] = data["Question"].apply(lambda x: 'Q'+str(Q[x]+1))
data['Q_group'] = data["Question Group"].apply(lambda x: 'G'+str(Q_group[x]+1) \
                                               if pd.isnull(x)==False else None)

# %% [markdown]
# ### Manually categorize the Respones to 7 groups
# Yes, No, Often, Maybe, Rare, N/A, Neutral

# %%
data['Response'].value_counts()
# Out:
# No                                                                                                                                                                                                                                                                                   6660
# I don't know                                                                                                                                                                                                                                                                         4132
# Maybe                                                                                                                                                                                                                                                                                4043
# Yes                                                                                                                                                                                                                                                                                  3990
# None did                                                                                                                                                                                                                                                                             2195
# Some of them                                                                                                                                                                                                                                                                         1690
# Some did                                                                                                                                                                                                                                                                             1444
# None of them                                                                                                                                                                                                                                                                         1430
# Not applicable to me                                                                                                                                                                                                                                                                 1401
# Some of my previous employers                                                                                                                                                                                                                                                        1394
# FALSE                                                                                                                                                                                                                                                                                1048
# Sometimes                                                                                                                                                                                                                                                                             851
# No, at none of my previous employers                                                                                                                                                                                                                                                  846
# Somewhat open                                                                                                                                                                                                                                                                         640
# Often                                                                                                                                                                                                                                                                                 603
# N/A (not currently aware)                                                                                                                                                                                                                                                             582
# Yes, I think it would                                                                                                                                                                                                                                                                 563
# Yes, I think they would                                                                                                                                                                                                                                                               403
# I was aware of some                                                                                                                                                                                                                                                                   384
# Rarely                                                                                                                                                                                                                                                                                374
# No, none did                                                                                                                                                                                                                                                                          372
# Yes, all of them                                                                                                                                                                                                                                                                      362
# I am not sure                                                                                                                                                                                                                                                                         352
# No, I don't think they would                                                                                                                                                                                                                                                          348
# Maybe/Not sure                                                                                                                                                                                                                                                                        346
# Yes, they all did                                                                                                                                                                                                                                                                     315
# Somewhat easy                                                                                                                                                                                                                                                                         281
# Yes, I observed                                                                                                                                                                                                                                                                       264
# Very open                                                                                                                                                                                                                                                                             251
# Very easy                                                                                                                                                                                                                                                                             220
#                                                                                                                                                                                                                                                                                      ...
# I would only discuss my mental health issues with a person after I have established that I can trust them.  I also want to show that it will not affect my job performance before I reveal any sort of personal issues.                                                                 1
# If I had mobility problems that required an accessible office or special accomodations, I'd want to make sure those were available                                                                                                                                                      1
# Same reason. Could cause trouble to keep silent.                                                                                                                                                                                                                                        1
# Just seems really personal and I would worry about that affecting the out come. Not everyone is aware of how that issue would affect someone's work. Or how it could. Not every company has good policies around keeping up to date on how an employee is doing.                        1
# A negative count against me for the job                                                                                                                                                                                                                                                 1
# Also seems highly likely to be irrelevant at the point that I am in an interview.                                                                                                                                                                                                       1
# I feel that is too early in the process. Guess it would depend on how serious I was about working for and how serious a company was about hiring me.                                                                                                                                    1
# I may not bring up a mental health issue in an interview with a potential employer, because I would be afraid that it might influence their decision about whether or not to hire me. They might view me as unstable or unqualified to properly do my job.                              1
# Same as before; lack of worker protections and proof that non-hire was result of disclosure of condition                                                                                                                                                                                1
# It's a weakness; and you mostly want to talk about your strenghts                                                                                                                                                                                                                       1
# would not if I was not 100% sure that the disclosure would not affect my application                                                                                                                                                                                                    1
# I have fibromyalgia which still isn't accepted fully in the medical community, so I don't believe it would be handled well by employers (or anybody, really).                                                                                                                           1
# Because I would be scared they would think that it affects my work and I'm not worth hiring.                                                                                                                                                                                            1
# If it didn't affect my work performance it would be none of their concern                                                                                                                                                                                                               1
# I would be afraid of being excluded from consideration due to my occasional back problems. I would only bring it up if it directly impacted the job                                                                                                                                     1
# I would want to set expectations of my ability from the start                                                                                                                                                                                                                           1
# I would not want to work for an employer that reacted negatively to a physical health issue. I think it's a good test to ensure that they're the kind of employer I'd want to work for.                                                                                                 1
# can't imagine this making my desired outcome more likely                                                                                                                                                                                                                                1
# I think the only time would be with "on call" work (i.e. Being available 24/7 with no set schedule) as this causes far too much stress in my life. I refuse, and have quit, jobs that rely on this method. The job that I quit was promised to have a schedule in the interview.        1
# I'm afraid it would impact my ability to get a job.                                                                                                                                                                                                                                     1
# I'm lucky that I'm mostly functional even when not doing well so I wouldn't disclose until I was at the company and had a better idea of how people react to it.                                                                                                                        1
# Because it's common                                                                                                                                                                                                                                                                     1
# If it relates to schedule availability, etc.  (Eg, can't work during certain hours, need frequent breaks, etc.)                                                                                                                                                                         1
# Rather not bring up something that would affect my chances of being hired. (Yes, it's illegal to discriminate that way, but that doesn't mean that doesn't happen, yeah?)                                                                                                               1
# Under UK law it's none of their business at that stage.                                                                                                                                                                                                                                 1
# Stigma, mainly.                                                                                                                                                                                                                                                                         1
# Correctness and openness the base for a healthy wirk relationship                                                                                                                                                                                                                       1
# Fear that the employer would consider additional health insurance expense and would doubt my ability to execute my work.                                                                                                                                                                1
# ?                                                                                                                                                                                                                                                                                       1
# If it affected my ability to perform at the job I would bring it up.                                                                                                                                                                                                                    1
# Name: Response, Length: 2078, dtype: int64

# %%
r = {"No": "No",
     "None did": "No",
     "None of them": "No",
     "FALSE": "No",
     "No, at none of my previous employers": "No",
     "No, none did": "No",
     "No, I don't think they would": "No", 
     "No, I don't think it would": "No",
     "No, because it would impact me negatively": "No",
     "Never": "No",
     "Very difficult": "No",
     "No, I only became aware later": "No",
     "False": "No",
     "Not open at all": "No",
     "No, I don't know any": "No",
     "No, because it doesn't matter": "No",
     "No, they do not": "No",
     
     "Yes": "Yes",
     "Yes, I think it would": "Yes",
     "Yes, I think they would": "Yes",
     "Yes, all of them": "Yes",
     "Yes, they all did": "Yes",
     "Yes, I observed": "Yes",
     "Very open": "Yes",
     "Very easy": "Yes",
     "Yes, at all of my previous employers": "Yes",
     "True": "Yes",
     "TRUE": "Yes",
     "Yes, I was aware of all of them": "Yes",
     "Yes, always": "Yes",
     "Yes, I experienced": "Yes",
     "Yes, it has": "Yes",
     "Yes, I know several": "Yes",
     "Yes, they do": "Yes",
     "76-100%": "Yes",
        
     "Often": "Often",
     "51-75%": "Often",
     
     "Rarely": "Rare",
     "1-25%": "Rare",
     
     "Maybe": "Maybe",
     "Some of them": "Maybe",
     "Some did": "Maybe",
     "Some of my previous employers": "Maybe",
     "Sometimes": "Maybe",
     "Somewhat open": "Maybe",
     "I was aware of some": "Maybe",
     "Maybe/Not sure": "Maybe",
     "Somewhat easy": "Maybe",
     "Somewhat not open": "Maybe",
     "Somewhat difficult": "Maybe",
     "Sometimes, if it comes up": "Maybe",
     "I know some": "Maybe",
     "26-50%": "Maybe",
     
     "I don't know": "N/A",
     "Not applicable to me": "N/A",
     "N/A (not currently aware)": "N/A",
     "I am not sure": "N/A",
     "I'm not sure": "N/A",
     "Not applicable to me (I do not have a mental illness)": "N/A",
     "Not eligible for coverage / N/A": "N/A",
     "Unsure": "N/A",
     "Stigma": "N/A",
     "Stigma.": "N/A",
     
     "Neither easy nor difficult": "Neutral",
     "Neutral": "Neutral"
    }

# %%
## add newcolum (simplified respones)
data['A'] = data["Response"].apply(lambda x: r[x] if x in r.keys() else "Others")

# %%
# save the result
data = data[["ResponseID","Q","Q_group","A"]]
data.to_csv('data/question.csv', index=False)

# %% [markdown]
# ### save the list of the questions and question groups

# %%
question = pd.DataFrame(list(q), columns=["Question"])
question.to_csv('data/question_list.csv', index=False)
question_group = pd.DataFrame(list(qg), columns=["Question_Group"])
question_group.to_csv('data/question_group_list.csv', index=False)

# %% [markdown]
# --------------------------

# %% [markdown]
# ### Add country code and state code

# %%
data = pd.read_csv('data/data.csv', engine="python")
data = data.iloc[:,0:-4]
data = data.drop_duplicates()
data.head()
# Out:
#     ResponseID  Are you selfemployed  \
# 0       r00000                 False
# 42      r00001                 False
# 84      r00002                 False
# 126     r00003                  True
# 168     r00004                 False
#
#     How many employees does your company or organization have  \
# 0                                               26-100
# 42                                                6-25
# 84                                                6-25
# 126                                                NaN
# 168                                               6-25
#
#     Is your employer primarily a tech companyorganization  \
# 0                                                 True
# 42                                                True
# 84                                                True
# 126                                                NaN
# 168                                              False
#
#     Is your primary role within your company related to techIT  \
# 0                                                  NaN
# 42                                                 NaN
# 84                                                 NaN
# 126                                                NaN
# 168                                               True
#
#      Do you have previous employers  \
# 0                              True
# 42                             True
# 84                             True
# 126                            True
# 168                            True
#
#     Do you have a family history of mental illness  \
# 0                                               No
# 42                                             Yes
# 84                                              No
# 126                                             No
# 168                                            Yes
#
#     Have you had a mental health disorder in the past  \
# 0                                                 Yes
# 42                                                Yes
# 84                                              Maybe
# 126                                               Yes
# 168                                               Yes
#
#     Do you currently have a mental health disorder  \
# 0                                               No
# 42                                             Yes
# 84                                              No
# 126                                            Yes
# 168                                            Yes
#
#     If yes, what conditions have you been diagnosed with  ...  \
# 0                                                  NaN    ...
# 42   Anxiety Disorder (Generalized, Social, Phobia,...    ...
# 84                                                 NaN    ...
# 126  Anxiety Disorder (Generalized, Social, Phobia,...    ...
# 168  Anxiety Disorder (Generalized, Social, Phobia,...    ...
#
#     Have you ever sought treatment for a mental health issue from a mental health professional  \
# 0                                                False
# 42                                                True
# 84                                                True
# 126                                               True
# 168                                               True
#
#      What is your age What is your gender   Age Group  \
# 0                39.0                 Male      36-40
# 42               29.0                 Male      26-30
# 84               38.0                 Male      36-40
# 126              43.0                 Male      41-45
# 168              43.0               Female      41-45
#
#      What country do you live in What US state or territory do you live in  \
# 0                 United Kingdom                                       NaN
# 42      United States of America                                  Illinois
# 84                United Kingdom                                       NaN
# 126               United Kingdom                                       NaN
# 168     United States of America                                  Illinois
#
#     What country do you work in What US state or territory do you work in  \
# 0                United Kingdom                                       NaN
# 42     United States of America                                  Illinois
# 84               United Kingdom                                       NaN
# 126              United Kingdom                                       NaN
# 168    United States of America                                  Illinois
#
#     Which of the following best describes your work position  \
# 0                                   Back-end Developer
# 42              Back-end Developer|Front-end Developer
# 84                                  Back-end Developer
# 126                               Supervisor/Team Lead
# 168  Executive Leadership|Supervisor/Team Lead|Dev ...
#
#     Do you work remotely
# 0              Sometimes
# 42                 Never
# 84                Always
# 126            Sometimes
# 168            Sometimes
#
# [5 rows x 23 columns]

# %%
state2code = pd.read_csv('USPS.csv')
state2code = dict(zip(state2code['state'], state2code['USPS']))

# %%
data['live_country_code'] = \
data["What country do you live in"].apply(lambda x: name2code(x) if x!="Other" else None)

# %%
data['work_country_code'] = \
data["What country do you work in"].apply(lambda x: name2code(x)if x!="Other" else None)

# %%
data['live_state_code'] = \
data['What US state or territory do you live in'].apply(lambda x: state2code[x] if pd.isnull(x)==False else None)

# %%
data['work_state_code'] = \
data['What US state or territory do you work in'].apply(lambda x: state2code[x] if pd.isnull(x)==False else None)

# %%
data.to_csv('data/data_code.csv', index=False)
